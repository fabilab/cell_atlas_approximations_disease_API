# %% [markdown]
# # AtlasApprox Diseases API Tutorial
#
# ## Introduction
#
# Welcome to the AtlasApprox Diseases API tutorial. This tutorial will guide you through the installation and basic usage of the `atlasapprox_diseases` package.

# %% [markdown]
# ## Installation
#
# To use the atlasapprox_diseases package, you need to have `pandas` and `requests` version 2.32.1 installed. You can install these dependencies using pip:
#
# To install the `atlasapprox_diseases` package, use `pip`. Please note that this is a test version available on Test PyPI. Ensure that you are using Python version 3.11 or above.
#
# ```bash
# pip install -i https://test.pypi.org/simple/ atlasapprox-diseases

# %%
pip install -i https://test.pypi.org/simple/ atlasapprox-diseases
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting atlasapprox-diseases
#   Using cached https://test-files.pythonhosted.org/packages/67/e9/fed6747cd0f8618edc15a118bbed9802dacca38cc301f0dba437e74e303f/atlasapprox_diseases-0.1.13-py3-none-any.whl (3.3 kB)
# Requirement already satisfied: requests<=2.32.1,>=2.25.1 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from atlasapprox-diseases) (2.32.1)
# Requirement already satisfied: pandas>=1.2.4 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from atlasapprox-diseases) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.4->atlasapprox-diseases) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.4->atlasapprox-diseases) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.4->atlasapprox-diseases) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from pandas>=1.2.4->atlasapprox-diseases) (2024.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from requests<=2.32.1,>=2.25.1->atlasapprox-diseases) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from requests<=2.32.1,>=2.25.1->atlasapprox-diseases) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from requests<=2.32.1,>=2.25.1->atlasapprox-diseases) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from requests<=2.32.1,>=2.25.1->atlasapprox-diseases) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/yingxu/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->atlasapprox-diseases) (1.16.0)
# Installing collected packages: atlasapprox-diseases
# Successfully installed atlasapprox-diseases-0.1.13
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Quick Start

# %% [markdown]
# ### Start the API
#
# First, import the `API` class from the `atlasapprox_diseases` package and create an instance of the `API`:

# %%
from atlasapprox_diseases import API

# Initialize the API
api = API()

# %% [markdown]
# ### Example 1: Differential cell type abundance (using disease keyword)
#
#
# Differential cell type abundance analysis helps identify how the proportions of different cell types change between normal and disease conditions.
#
# Let's fetch differential cell type abundance for a specific disease keyword. For example, **"covid"**

# %%
df_celltype_abundance = api.diff_celltype_abundance(disease_keyword="covid")

# %% [markdown]
# #### Output
#
# Each row in the result represents a specific combination of disease, dataset, and cell type, showing how the abundance of that cell type differs between the disease and normal conditions. The delta_fraction column specifically highlights the change in proportion of that cell type between the two conditions.

# %%
# Display the the result as pandas dataframeb

df_celltype_abundance
# Out:
#      disease                                      dataset_title  \
# 0   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 1   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 2   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 3   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# ..       ...                                                ...
# 57  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 58  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 59  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 60  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 61  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
#
#                                     cell_type          comparison condition  \
# 0                     hematopoietic stem cell  disease vs. normal   disease
# 1                                 erythrocyte  disease vs. normal   disease
# 2                                    platelet  disease vs. normal   disease
# 3                                  lymphocyte  disease vs. normal   disease
# 4                         natural killer cell  disease vs. normal   disease
# ..                                        ...                 ...       ...
# 57                          IgG memory B cell  disease vs. normal   disease
# 58   effector CD4-positive, alpha-beta T cell  disease vs. normal   disease
# 59   effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 60  IgG-negative class switched memory B cell  disease vs. normal   disease
# 61                      intermediate monocyte  disease vs. normal   disease
#
#    condition_baseline  normal_count  disease_count  normal_total_count  \
# 0              normal           104            220               15765
# 1              normal           178           1259               15765
# 2              normal            63            464               15765
# 3              normal           146            570               15765
# 4              normal          4558           2040               15765
# ..                ...           ...            ...                 ...
# 57             normal           607           1308               17590
# 58             normal          1321           1813               17590
# 59             normal          1067           1875               17590
# 60             normal          1285           2738               17590
# 61             normal           201            342               17590
#
#     disease_total_count  normal_fraction  disease_fraction  delta_fraction
# 0                 25540         0.006597          0.008614        0.002017
# 1                 25540         0.011291          0.049295        0.038004
# 2                 25540         0.003996          0.018168        0.014171
# 3                 25540         0.009261          0.022318        0.013057
# 4                 25540         0.289121          0.079875       -0.209247
# ..                  ...              ...               ...             ...
# 57                31463         0.034508          0.041573        0.007064
# 58                31463         0.075099          0.057623       -0.017476
# 59                31463         0.060659          0.059594       -0.001066
# 60                31463         0.073053          0.087023        0.013970
# 61                31463         0.011427          0.010870       -0.000557
#
# [62 rows x 13 columns]

# %% [markdown]
# #### Sorting cell types by abundance change (delta fraction)
#
# You can also sort the DataFrame by **delta_fraction** in descending order to view the cell types that show the greatest increase in abundance in the disease condition compared to the normal condition

# %%
df_sorted_descending = df_celltype_abundance.sort_values(by='delta_fraction', ascending=False)

df_sorted_descending
# Out:
#      disease                                      dataset_title  \
# 12  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 50  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 29  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 20  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 23  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# ..       ...                                                ...
# 37  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 17  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 53  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 36  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
#
#                                            cell_type          comparison  \
# 12                                classical monocyte  disease vs. normal
# 50                                          platelet  disease vs. normal
# 29                                        neutrophil  disease vs. normal
# 20                                   IgG plasmablast  disease vs. normal
# 23  activated CD4-positive, alpha-beta T cell, human  disease vs. normal
# ..                                               ...                 ...
# 37                            non-classical monocyte  disease vs. normal
# 17   effector memory CD8-positive, alpha-beta T cell  disease vs. normal
# 53                               natural killer cell  disease vs. normal
# 36                                classical monocyte  disease vs. normal
# 4                                natural killer cell  disease vs. normal
#
#    condition condition_baseline  normal_count  disease_count  \
# 12   disease             normal          1669           6921
# 50   disease             normal           253           3281
# 29   disease             normal             0           1891
# 20   disease             normal            20           1087
# 23   disease             normal            17           1022
# ..       ...                ...           ...            ...
# 37   disease             normal          2547           1032
# 17   disease             normal          2651           2727
# 53   disease             normal          3915           4005
# 36   disease             normal         16158          10554
# 4    disease             normal          4558           2040
#
#     normal_total_count  disease_total_count  normal_fraction  \
# 12               15765                25540         0.105867
# 50               17590                31463         0.014383
# 29               45787                45170         0.000000
# 20               15765                25540         0.001269
# 23               15765                25540         0.001078
# ..                 ...                  ...              ...
# 37               45787                45170         0.055627
# 17               15765                25540         0.168157
# 53               17590                31463         0.222570
# 36               45787                45170         0.352895
# 4                15765                25540         0.289121
#
#     disease_fraction  delta_fraction
# 12          0.270987        0.165119
# 50          0.104281        0.089898
# 29          0.041864        0.041864
# 20          0.042561        0.041292
# 23          0.040016        0.038937
# ..               ...             ...
# 37          0.022847       -0.032780
# 17          0.106774       -0.061384
# 53          0.127292       -0.095277
# 36          0.233651       -0.119244
# 4           0.079875       -0.209247
#
# [62 rows x 13 columns]

# %% [markdown]
# #### Visualizing the data
#
# To better understand the changes in cell type abundance, you can create visualizations. Here's how you can use the data to create bar plots showing the differential cell type abundance for each dataset using matplotlib:

# %%
import matplotlib.pyplot as plt

# %%
# Function to plot differential cell type abundance for each dataset
def plot_diff_celltype_abundance(df):
    # Group by dataset_title
    grouped = df.groupby('dataset_title')
    
    for dataset_title, group in grouped:
        plt.figure(figsize=(6, 5))
        plt.barh(group['cell_type'], group['delta_fraction'])
        plt.xlabel('Delta Fraction')
        plt.title(f'Differential cell type abundance for {dataset_title}')
        plt.grid(axis='x')
        plt.show()

# Plot the differential cell type abundance
plot_diff_celltype_abundance(df_celltype_abundance)

# %% [markdown]
# ### Example 2.1: Differential gene expression for all cell types (using disease keyword)
#
# In this example, we will fetch differential gene expression data for a specific disease keyword and the top 5 upregulated and downregulated genes for all available cell types.
#
#
# #### Step 1: Fetch Differential Gene Expression Data
#
# We use the diff_gene_expression method from the API to retrieve the data. This method requires two parameters: 1) the disease keyword, and 2) the number of top genes to display.

# %%
df_gene_expression_all = api.diff_gene_expression(
    disease_keyword="covid",
    top_n=5
)

# %% [markdown]
# #### Output
#
# The resulting DataFrame (df_gene_expression) contains the top 5 (up & down) differentially expressed genes for across all available cell types in all available `covid` related datasets. Each row in the DataFrame represents a differentially expressed gene, providing detailed information on its expression changes between the disease and normal conditions.

# %%
df_gene_expression_all
# Out:
#       disease                                      dataset_title  \
# 0    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 1    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 2    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 3    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# ..        ...                                                ...
# 595  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 596  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 597  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 598  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 599  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
#
#                    cell_type          comparison condition condition_baseline  \
# 0    hematopoietic stem cell  disease vs. normal   disease             normal
# 1    hematopoietic stem cell  disease vs. normal   disease             normal
# 2    hematopoietic stem cell  disease vs. normal   disease             normal
# 3    hematopoietic stem cell  disease vs. normal   disease             normal
# 4    hematopoietic stem cell  disease vs. normal   disease             normal
# ..                       ...                 ...       ...                ...
# 595    intermediate monocyte  disease vs. normal   disease             normal
# 596    intermediate monocyte  disease vs. normal   disease             normal
# 597    intermediate monocyte  disease vs. normal   disease             normal
# 598    intermediate monocyte  disease vs. normal   disease             normal
# 599    intermediate monocyte  disease vs. normal   disease             normal
#
#     regulation     feature_name  unit  normal_expr  disease_expr  \
# 0           up  ENSG00000132530  cptt     1.412743      4.954321
# 1           up  ENSG00000137959  cptt     0.000000      2.765172
# 2           up  ENSG00000142089  cptt     0.437597      3.138294
# 3           up  ENSG00000157601  cptt     0.726632      3.308897
# 4           up  ENSG00000105810  cptt     4.452785      7.156817
# ..         ...              ...   ...          ...           ...
# 595       down  ENSG00000229807  cptt     3.813986      1.847296
# 596       down  ENSG00000115523  cptt    16.335957     10.319922
# 597       down  ENSG00000211829  cptt     1.124900      0.345459
# 598       down  ENSG00000203747  cptt     1.783551      0.729117
# 599       down  ENSG00000265206  cptt     1.181824      0.486182
#
#      log_transformed   log2_fc  normal_fraction  disease_fraction  \
# 0              False  1.303262         0.153846          0.504545
# 1              False  1.912716         0.000000          0.290909
# 2              False  1.525376         0.048077          0.336364
# 3              False  1.319358         0.076923          0.345455
# 4              False  0.581013         0.432692          0.681818
# ..               ...       ...              ...               ...
# 595            False -0.757640         0.696517          0.447368
# 596            False -0.614903         0.736318          0.500000
# 597            False -0.659297         0.407960          0.178363
# 598            False -0.686891         0.592040          0.365497
# 599            False -0.553924         0.646766          0.423977
#
#      delta_fraction
# 0          0.350699
# 1          0.290909
# 2          0.288287
# 3          0.268531
# 4          0.249126
# ..              ...
# 595       -0.249149
# 596       -0.236318
# 597       -0.229598
# 598       -0.226543
# 599       -0.222790
#
# [600 rows x 16 columns]

# %% [markdown]
# ### Example 2.2: Differential gene expression for a specfic cell type (using disease keyword)
#
# In this example, we will fetch differential gene expression data for a specific disease keyword, cell type, and the top 5 upregulated and downregulated genes.
#
# #### Step 1: Fetch Differential Gene Expression Data
#
# We use the diff_gene_expression method from the API to retrieve the data. This method requires the disease keyword, the cell type of interest, and the number of top genes to display.

# %%
df_gene_expression_cell_type_specific = api.diff_gene_expression(
    disease_keyword="covid",
    cell_type_keyword="T cell",
    top_n=5
)

# %% [markdown]
# #### Output
#
# The resulting DataFrame (df_gene_expression) contains the top differentially expressed genes for cell types that contain the keyword `T cell` in all available `covid` related datasets. Each row in the DataFrame represents a differentially expressed gene, providing detailed information on its expression changes between the disease and normal conditions.

# %%
df_gene_expression_cell_type_specific
# Out:
#       disease                                      dataset_title  \
# 0    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 1    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 2    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 3    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# ..        ...                                                ...
# 185  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 186  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 187  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 188  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 189  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
#
#                                     cell_type          comparison condition  \
# 0                          gamma-delta T cell  disease vs. normal   disease
# 1                          gamma-delta T cell  disease vs. normal   disease
# 2                          gamma-delta T cell  disease vs. normal   disease
# 3                          gamma-delta T cell  disease vs. normal   disease
# 4                          gamma-delta T cell  disease vs. normal   disease
# ..                                        ...                 ...       ...
# 185  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 186  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 187  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 188  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 189  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
#
#     condition_baseline regulation     feature_name  unit  normal_expr  \
# 0               normal         up  ENSG00000036448  cptt     0.301473
# 1               normal         up  ENSG00000168329  cptt     2.552426
# 2               normal         up  ENSG00000100453  cptt     3.172268
# 3               normal         up  ENSG00000203747  cptt     3.855826
# 4               normal         up  ENSG00000132530  cptt     2.850255
# ..                 ...        ...              ...   ...          ...
# 185             normal       down  ENSG00000134539  cptt     2.013945
# 186             normal       down  ENSG00000110046  cptt     2.271817
# 187             normal       down  ENSG00000139187  cptt     1.726592
# 188             normal       down  ENSG00000179344  cptt     1.845590
# 189             normal       down  ENSG00000211829  cptt     2.242822
#
#      disease_expr  log_transformed   log2_fc  normal_fraction  \
# 0        6.489651            False  2.524753         0.030151
# 1        6.476168            False  1.073494         0.276382
# 2        6.708242            False  0.885570         0.331658
# 3        6.841932            False  0.691492         0.396985
# 4        5.848413            False  0.830816         0.306533
# ..            ...              ...       ...              ...
# 185      1.219684            False -0.441298         0.500469
# 186      1.442214            False -0.421903         0.667291
# 187      0.936356            False -0.493754         0.538894
# 188      0.826244            False -0.639848         0.481724
# 189      0.558052            False -1.057506         0.276476
#
#      disease_fraction  delta_fraction
# 0            0.654514        0.624363
# 1            0.644097        0.367715
# 2            0.664931        0.333272
# 3            0.675347        0.278362
# 4            0.578125        0.271592
# ..                ...             ...
# 185          0.291200       -0.209269
# 186          0.458667       -0.208625
# 187          0.332800       -0.206094
# 188          0.280000       -0.201724
# 189          0.090667       -0.185809
#
# [190 rows x 16 columns]

# %% [markdown]
# ### Example 3: Fetch Metadata
#
# For advanced users, we also provide a way to fetch metadata for further analysis and filtering.
#
# Let's fetch metadata for a specific disease keyword. For example, **"covid"**:

# %%
# Fetch metadata for "covid", or replace it with any disease keyword

df_metadata = api.get_metadata(disease_keyword="covid")

# %% [markdown]
# #### Sample Metadata Output

# %%
df_metadata
# Out:
#                               unique_id   disease  cell_type_number  \
# 0  6c9402a9-13cd-55a4-daf5-ad6002360886  COVID-19                26
# 1  2d592d70-812d-7652-77d6-59e4bdb2223c  COVID-19                14
# 2  ef3a1496-0ccd-14c6-49e8-5e2159d304a5  COVID-19                22
#
#                              dataset_id  \
# 0  055ca631-6ffb-40de-815e-b931e10718c0
# 1  de2c780c-1747-40bd-9ccf-9588ec186cee
# 2  5e717147-0f75-4de1-8bd2-6fda01b8d75f
#
#                                      collection_name  unit  log_transformed  \
# 0  A Web Portal and Workbench for Biological Diss...  cptt            False
# 1  Immunophenotyping of COVID-19 and influenza hi...  cptt            False
# 2  A Web Portal and Workbench for Biological Diss...  cptt            False
#
#    has_normal_baseline
# 0                 True
# 1                 True
# 2                 True

# %% [markdown]
# #### Understanding the metadata
#
# Each row in the `get_metadata` result represents a unique combination of disease and the dataset. The attributes stored in the metadata provide detailed information about each dataset:
#
# 1. **unique_id**: A unique identifier for each combination of disease and dataset.
# 2. **disease**: The disease associated with the dataset.
# 3. **cell_type_number**: The number of distinct cell types present in this dataset.
# 4. **dataset_id**: A unique identifier for the dataset file.
# 5. **collection_name**: The name of the collection or study the dataset belongs to.
# 6. **unit**: The unit of measurement for the gene expression data (e.g., 'cptt', 'cpm', 'raw').
# 7. **log_transformed**: Indicates whether the gene expression data has been log-transformed.
# 8. **has_normal_baseline**: Indicates whether the dataset includes a normal baseline for comparison.

# %% [markdown]
# #### Filtering Metadata (with 2 examples)
#
# You can filter the metadata to extract specific information. Let's demonstrate how to filter rows based on certain criteria.
#
# **Example 1:** if you want to get a list of all datasets related to COVID-19 with more than 20 cell types:

# %%
# Filter metadata for datasets related to COVID-19 with more than 20 cell types

filtered_metadata = df_metadata[(df_metadata['disease'] == 'COVID-19') & (df_metadata['cell_type_number'] > 20)]

# Display the filtered metadata
filtered_metadata
# Out:
#                               unique_id   disease  cell_type_number  \
# 0  6c9402a9-13cd-55a4-daf5-ad6002360886  COVID-19                26
# 2  ef3a1496-0ccd-14c6-49e8-5e2159d304a5  COVID-19                22
#
#                              dataset_id  \
# 0  055ca631-6ffb-40de-815e-b931e10718c0
# 2  5e717147-0f75-4de1-8bd2-6fda01b8d75f
#
#                                      collection_name  unit  log_transformed  \
# 0  A Web Portal and Workbench for Biological Diss...  cptt            False
# 2  A Web Portal and Workbench for Biological Diss...  cptt            False
#
#    has_normal_baseline
# 0                 True
# 2                 True

# %% [markdown]
# ### Example 4: Use unique ids from the metadata result to inqurie differential data

# %% [markdown]
# ### 4.1: Differential cell type abundance (using unique ids)

# %%
# Fetch differential cell type abundance using unique IDs (ids selected from the first example)

unique_ids = ["6c9402a9-13cd-55a4-daf5-ad6002360886", "ef3a1496-0ccd-14c6-49e8-5e2159d304a5"]
df_cell_abundance_by_ids = api.diff_celltype_abundance(unique_ids=unique_ids)

# %%
# Display the result as panda dataframe
df_cell_abundance_by_ids
# Out:
#      disease                                      dataset_title  \
# 0   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 1   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 2   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 3   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 5   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 6   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 7   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 8   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 9   COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 10  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 11  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 12  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 13  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 14  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 15  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 16  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 17  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 18  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 19  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 20  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 21  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 22  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 23  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 24  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 25  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 26  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 27  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 28  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 29  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 30  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 31  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 32  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 33  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 34  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 35  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 36  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 37  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 38  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 39  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 40  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 41  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 42  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 43  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 44  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 45  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 46  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 47  COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
#
#                                             cell_type          comparison  \
# 0                             hematopoietic stem cell  disease vs. normal
# 1                                         erythrocyte  disease vs. normal
# 2                                            platelet  disease vs. normal
# 3                                          lymphocyte  disease vs. normal
# 4                                 natural killer cell  disease vs. normal
# 5                                          neutrophil  disease vs. normal
# 6                                 immature neutrophil  disease vs. normal
# 7                                       memory B cell  disease vs. normal
# 8                                        naive B cell  disease vs. normal
# 9                                  gamma-delta T cell  disease vs. normal
# 10                                  regulatory T cell  disease vs. normal
# 11                          transitional stage B cell  disease vs. normal
# 12                                 classical monocyte  disease vs. normal
# 13                             non-classical monocyte  disease vs. normal
# 14  naive thymus-derived CD4-positive, alpha-beta ...  disease vs. normal
# 15  naive thymus-derived CD8-positive, alpha-beta ...  disease vs. normal
# 16     central memory CD4-positive, alpha-beta T cell  disease vs. normal
# 17    effector memory CD8-positive, alpha-beta T cell  disease vs. normal
# 18  CD16-negative, CD56-bright natural killer cell...  disease vs. normal
# 19                           mucosal invariant T cell  disease vs. normal
# 20                                    IgG plasmablast  disease vs. normal
# 21                                    IgA plasmablast  disease vs. normal
# 22                        conventional dendritic cell  disease vs. normal
# 23   activated CD4-positive, alpha-beta T cell, human  disease vs. normal
# 24                 plasmacytoid dendritic cell, human  disease vs. normal
# 25                          double negative thymocyte  disease vs. normal
# 26                                           platelet  disease vs. normal
# 27                                         lymphocyte  disease vs. normal
# 28                                natural killer cell  disease vs. normal
# 29                                         neutrophil  disease vs. normal
# 30                                immature neutrophil  disease vs. normal
# 31                                      memory B cell  disease vs. normal
# 32                                       naive B cell  disease vs. normal
# 33                                 gamma-delta T cell  disease vs. normal
# 34                                  regulatory T cell  disease vs. normal
# 35                          transitional stage B cell  disease vs. normal
# 36                                 classical monocyte  disease vs. normal
# 37                             non-classical monocyte  disease vs. normal
# 38  naive thymus-derived CD4-positive, alpha-beta ...  disease vs. normal
# 39  naive thymus-derived CD8-positive, alpha-beta ...  disease vs. normal
# 40     central memory CD4-positive, alpha-beta T cell  disease vs. normal
# 41    effector memory CD8-positive, alpha-beta T cell  disease vs. normal
# 42  CD16-negative, CD56-bright natural killer cell...  disease vs. normal
# 43                           mucosal invariant T cell  disease vs. normal
# 44                                        plasmablast  disease vs. normal
# 45                        conventional dendritic cell  disease vs. normal
# 46                 plasmacytoid dendritic cell, human  disease vs. normal
# 47                          double negative thymocyte  disease vs. normal
#
#    condition condition_baseline  normal_count  disease_count  \
# 0    disease             normal           104            220
# 1    disease             normal           178           1259
# 2    disease             normal            63            464
# 3    disease             normal           146            570
# 4    disease             normal          4558           2040
# 5    disease             normal            28            167
# 6    disease             normal             2            175
# 7    disease             normal           453            501
# 8    disease             normal           710            842
# 9    disease             normal           199            576
# 10   disease             normal           197            292
# 11   disease             normal           706            927
# 12   disease             normal          1669           6921
# 13   disease             normal           753            538
# 14   disease             normal          1005           1695
# 15   disease             normal           455            406
# 16   disease             normal           955           1703
# 17   disease             normal          2651           2727
# 18   disease             normal           238             43
# 19   disease             normal           214             67
# 20   disease             normal            20           1087
# 21   disease             normal            66            890
# 22   disease             normal           202            249
# 23   disease             normal            17           1022
# 24   disease             normal           128             86
# 25   disease             normal            48             73
# 26   disease             normal           284            877
# 27   disease             normal           172            825
# 28   disease             normal          3433           4416
# 29   disease             normal             0           1891
# 30   disease             normal             0           1287
# 31   disease             normal          1530            331
# 32   disease             normal          2472           1590
# 33   disease             normal           732            723
# 34   disease             normal           494           1041
# 35   disease             normal           923            773
# 36   disease             normal         16158          10554
# 37   disease             normal          2547           1032
# 38   disease             normal          3990           5040
# 39   disease             normal           900            945
# 40   disease             normal          6226           6875
# 41   disease             normal          3455           5166
# 42   disease             normal           154            166
# 43   disease             normal          1133            469
# 44   disease             normal           191            648
# 45   disease             normal           574            275
# 46   disease             normal           378            136
# 47   disease             normal            41            110
#
#     normal_total_count  disease_total_count  normal_fraction  \
# 0                15765                25540         0.006597
# 1                15765                25540         0.011291
# 2                15765                25540         0.003996
# 3                15765                25540         0.009261
# 4                15765                25540         0.289121
# 5                15765                25540         0.001776
# 6                15765                25540         0.000127
# 7                15765                25540         0.028735
# 8                15765                25540         0.045036
# 9                15765                25540         0.012623
# 10               15765                25540         0.012496
# 11               15765                25540         0.044783
# 12               15765                25540         0.105867
# 13               15765                25540         0.047764
# 14               15765                25540         0.063749
# 15               15765                25540         0.028861
# 16               15765                25540         0.060577
# 17               15765                25540         0.168157
# 18               15765                25540         0.015097
# 19               15765                25540         0.013574
# 20               15765                25540         0.001269
# 21               15765                25540         0.004186
# 22               15765                25540         0.012813
# 23               15765                25540         0.001078
# 24               15765                25540         0.008119
# 25               15765                25540         0.003045
# 26               45787                45170         0.006203
# 27               45787                45170         0.003757
# 28               45787                45170         0.074978
# 29               45787                45170         0.000000
# 30               45787                45170         0.000000
# 31               45787                45170         0.033416
# 32               45787                45170         0.053989
# 33               45787                45170         0.015987
# 34               45787                45170         0.010789
# 35               45787                45170         0.020159
# 36               45787                45170         0.352895
# 37               45787                45170         0.055627
# 38               45787                45170         0.087143
# 39               45787                45170         0.019656
# 40               45787                45170         0.135977
# 41               45787                45170         0.075458
# 42               45787                45170         0.003363
# 43               45787                45170         0.024745
# 44               45787                45170         0.004171
# 45               45787                45170         0.012536
# 46               45787                45170         0.008256
# 47               45787                45170         0.000895
#
#     disease_fraction  delta_fraction
# 0           0.008614        0.002017
# 1           0.049295        0.038004
# 2           0.018168        0.014171
# 3           0.022318        0.013057
# 4           0.079875       -0.209247
# 5           0.006539        0.004763
# 6           0.006852        0.006725
# 7           0.019616       -0.009118
# 8           0.032968       -0.012069
# 9           0.022553        0.009930
# 10          0.011433       -0.001063
# 11          0.036296       -0.008487
# 12          0.270987        0.165119
# 13          0.021065       -0.026699
# 14          0.066366        0.002618
# 15          0.015897       -0.012965
# 16          0.066680        0.006102
# 17          0.106774       -0.061384
# 18          0.001684       -0.013413
# 19          0.002623       -0.010951
# 20          0.042561        0.041292
# 21          0.034847        0.030661
# 22          0.009749       -0.003064
# 23          0.040016        0.038937
# 24          0.003367       -0.004752
# 25          0.002858       -0.000186
# 26          0.019416        0.013213
# 27          0.018264        0.014508
# 28          0.097764        0.022786
# 29          0.041864        0.041864
# 30          0.028492        0.028492
# 31          0.007328       -0.026088
# 32          0.035200       -0.018789
# 33          0.016006        0.000019
# 34          0.023046        0.012257
# 35          0.017113       -0.003045
# 36          0.233651       -0.119244
# 37          0.022847       -0.032780
# 38          0.111578        0.024436
# 39          0.020921        0.001265
# 40          0.152203        0.016225
# 41          0.114368        0.038910
# 42          0.003675        0.000312
# 43          0.010383       -0.014362
# 44          0.014346        0.010174
# 45          0.006088       -0.006448
# 46          0.003011       -0.005245
# 47          0.002435        0.001540

# %% [markdown]
# ### 4.2: Differential gene expression (using unique ids)
#
# Fetch differential gene expression for specific unique IDs, cell type, and top N genes:

# %%
# Fetch differential gene expression using unique IDs
unique_ids = ["6c9402a9-13cd-55a4-daf5-ad6002360886", "2d592d70-812d-7652-77d6-59e4bdb2223c"]

df_gene_expression_by_ids = api.diff_gene_expression(
    unique_ids=unique_ids,
    cell_type_keyword="T cell",
    top_n=5
)

# %%
df_gene_expression_by_ids
# Out:
#       disease                                      dataset_title  \
# 0    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 1    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 2    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 3    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# 4    COVID-19  Individual Single-Cell RNA-seq PBMC Data from ...
# ..        ...                                                ...
# 115  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 116  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 117  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 118  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
# 119  COVID-19  Immunophenotyping of COVID-19 and influenza hi...
#
#                                     cell_type          comparison condition  \
# 0                          gamma-delta T cell  disease vs. normal   disease
# 1                          gamma-delta T cell  disease vs. normal   disease
# 2                          gamma-delta T cell  disease vs. normal   disease
# 3                          gamma-delta T cell  disease vs. normal   disease
# 4                          gamma-delta T cell  disease vs. normal   disease
# ..                                        ...                 ...       ...
# 115  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 116  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 117  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 118  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
# 119  effector CD8-positive, alpha-beta T cell  disease vs. normal   disease
#
#     condition_baseline regulation     feature_name  unit  normal_expr  \
# 0               normal         up  ENSG00000036448  cptt     0.301473
# 1               normal         up  ENSG00000168329  cptt     2.552426
# 2               normal         up  ENSG00000100453  cptt     3.172268
# 3               normal         up  ENSG00000203747  cptt     3.855826
# 4               normal         up  ENSG00000132530  cptt     2.850255
# ..                 ...        ...              ...   ...          ...
# 115             normal       down  ENSG00000134539  cptt     2.013945
# 116             normal       down  ENSG00000110046  cptt     2.271817
# 117             normal       down  ENSG00000139187  cptt     1.726592
# 118             normal       down  ENSG00000179344  cptt     1.845590
# 119             normal       down  ENSG00000211829  cptt     2.242822
#
#      disease_expr  log_transformed   log2_fc  normal_fraction  \
# 0        6.489651            False  2.524753         0.030151
# 1        6.476168            False  1.073494         0.276382
# 2        6.708242            False  0.885570         0.331658
# 3        6.841932            False  0.691492         0.396985
# 4        5.848413            False  0.830816         0.306533
# ..            ...              ...       ...              ...
# 115      1.219684            False -0.441298         0.500469
# 116      1.442214            False -0.421903         0.667291
# 117      0.936356            False -0.493754         0.538894
# 118      0.826244            False -0.639848         0.481724
# 119      0.558052            False -1.057506         0.276476
#
#      disease_fraction  delta_fraction
# 0            0.654514        0.624363
# 1            0.644097        0.367715
# 2            0.664931        0.333272
# 3            0.675347        0.278362
# 4            0.578125        0.271592
# ..                ...             ...
# 115          0.291200       -0.209269
# 116          0.458667       -0.208625
# 117          0.332800       -0.206094
# 118          0.280000       -0.201724
# 119          0.090667       -0.185809
#
# [120 rows x 16 columns]

# %% [markdown]
# ## Conclusion
#
# This tutorial provided a quick start guide to using the `atlasapprox_diseases` package. For more detailed information, refer to the official documentation.
